# %% [markdown]
# # Machine learning
#
# ## Goals
#
# Learn to perform:
# * Regression
# * Classification
# * Clustering
# * Scikit Learn
# * Scipy
#
# With projects such as:
# * Cancer detection
# * Predicting economic trends
# * Predicting customer churn
# * Recommendation engines
# * And many more
#
# ## Introduction
#
# Predictions based on previous experience.
# 1. Gather relevant data with relevent characteristics
# 2. Clean data (?)
# 3. Select a proper algorithm (?) to build a prediction model
# 4. Train the model
#
# > Machine learning is the subfiel of computer science that gives "computers the ability to lean without being explicitly programmed"
#
# With "without being explicitly programmed"
#
# example: interpretation of data -> extract relevant data (feature extration) -> set of rules to classify.
# Rules are hard to formulate generically. Instead, machine learning can be used to build a model which interprets all features and matches that to a known output. That way it learns the set of rules instead of being explicitly programmed.
#
# **Popular techniques**
#
# * Regression/Estimation: used for predicting a continuous value. For example, predicting things like the price of a house based on its characteristics, or to estimate the Co2 emission from a car’s engine.
# * A Classification technique is used for Predicting the class or category of a case, for example, if a cell is benign or malignant, or whether or not a customer will churn.
# * Clustering groups of similar cases, for example, can find similar patients, or can be used for customer segmentation in the banking field.
# * Association technique is used for finding items or events that often co-occur, for example, grocery items that are usually bought together by a particular customer.
# * Anomaly detection is used to discover abnormal and unusual cases, for example, it is used for credit card fraud detection.
# * Sequence mining is used for predicting the next event, for instance, the click-stream in websites.
# * Dimension reduction is used to reduce the size of data.
# * Recommendation systems, this associates people's preferences with others who have similar tastes, and recommends new items to them, such as books or movies.
#
# **Landscape**
#
# * Artificial Intelligence
#  * A general field with a broad scope including: Computer Vision, Language Processing, Creativity, and Summarization
# * Machine learning
#  * Branch in AI, focussing on the statistical side. Learning from big data sets (100+) and then apply what is learned to make predictions in new situations.
# * Deep learning
#  * A special field of Machine Learning where computers can actually learn and make intelligent decisions on their own
#
# ## Using Python for Machine Learning
#
# * numpy: for the datatypes
# * scipy: for the toolboxes
# * matplotlib: for plotting
# * pandas: for data handling
# * scikit learn: for ML algorithms and tools
#
# > Why not TensorFlow/Keras/PyTorch?
#
# These standard libraries assume clean data: no outliers, uniform definitions, edge cases(?).
#
# ## Supervised versus unsupervised algorithms
#
# **Supervised**
# How to teach a model?
# * Requires a labeled dataset
#  * The expected outcome is known beforehand
#  * Such a dataset has multiple rows of data entries (observations)
#  * Multiple attributes or features (cols) (filled using the same (single) definition)
#
# 2 types:
# * Classification: predicting discreet value (label, category)
# * Regression: predicting  a continous value
#
# **Unsupervised**
# * No labels (obviously)
# > May discover information not visable to human observation.
#
# Common types:
# * Dimension reduction / feature selection
# * Density estimation
# * Market basket analysis (association)
# * Clustering (discovering structure, summarization, and anomaly detection)

# %% [markdown]
# # Regression
#
# Predicting a continous value based on other (**related**) variables.
#
# Definitions:
# * dependant variable or state is the variable to predict
# * independant variables or explanatory variables are the inputs.
#
# (Simple/Multiple) (linear/non-linear) regression
# * simple vs multiple: one on one vs many on one relationship
# * linear/non-linear: linear/non-linear relationship between the dependant and independent variable(s)
#
# **Pros**
# * Easy to use and understand
# * Fast
# * No tuning
#
# **Cons**
#
#
#
# ## Model evaluation in Regression Models
#
# Accuracy metrics:
# * training accuracy: percentage of correct prediction when using the test dataset.
#   * A high percentage may indicate over-fitting -> trained to tight to the training data.
# * out of sample accuracy: percentage of correct predictions based on data the model has not yet seen.
#   * This is disired to transfer the model to new scenarios
#
# > alternative names? training loss?
#
# Possible approaches:
# 1. Train using the complete dataset and use a portion of the same dataset to test
#  * Test set is part of the train set.
#  * High training accuracy
#  * Low out of sample accuracy
# 2. Train/Test split: split the dataset into two: one part of training and one part for testing (ofc wihout the labels)
#  * Test set and train set are exclusive.
#  * More accurate "out of sample accuracy"
#  * Performance may depends on the split.
#
# **k-fold cross-validation**
# A method to determine the performance dependency on the splitting of data.
#
# Using (all) variations on the data split to train and test the data. For example, a 4 fold would split the data into 25% for testing and the remaining 75% for training. This can be repeated 4 times by moving the test data selecting by a qaurter of the data each step. Note that the model is rebuild on each iteration. For each iteration, the accuracy is kept and finally averaged to indicate the effect on the input split on "out of sample accuracy".
#
# **Error metrics**
#
# Next step compare predicted values to the actual values (the residuals).
# Error metrics: MSE
# * MAE: mean absolute error (easy to interpret)
# * MSE: mean square error (placed more weight on bigger errors)
# * RMSE: root mean square error (same as MSE but the output can be interpretted in terms of the input (data dimensions))
# * RAE: relative absolute error (relates the residual to a trivial (average) predictor)
# * RSE: relative squared error
# * R^2: popular metric for model accuracy, higher values indicate better fit.
#
# > When to use which? Good question... (out of scope)

# %% [markdown]
# House selling price prediction using regression?
